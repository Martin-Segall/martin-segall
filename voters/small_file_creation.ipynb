# %%
import pandas as pd
district1 = pd.read_csv("SWVF_1_22.txt")
district2 = pd.read_csv("SWVF_23_44.txt")
district3 = pd.read_csv("SWVF_45_66.txt")
district4 = pd.read_csv("SWVF_67_88.txt")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (20,25,26,58,64,74,78,82,87,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (20,25,26,58,64,73,74,75,78,82,87,93,96,97,100) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (20,25,26,60,73,75,78,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ...

# %%
sample1 = district1.sample(frac=1)
sample2 = district2.sample(frac=1)
sample3 = district3.sample(frac=1)
sample4 = district4.sample(frac=1)

# %%
sample1 = sample1.head(500)
sample1
# Out:
#           SOS_VOTERID  COUNTY_NUMBER  COUNTY_ID   LAST_NAME  FIRST_NAME  \
# 1589051  OH0016465400             21      98871       BROWN       HELEN
# 148478   OH0023001783              6      51247      SNEARY     JEFFERY
# 2017695  OH0016361359              2      28178      MUSSER      WARREN
# 1128282  OH0021885757             18    2541383    PINCKNEY     BRITANY
# 1952509  OH0013323099              9      19917      WALTON       LINDA
# 1870171  OH0024292091             21     265612       LENTZ     JEFFREY
# 2060288  OH0018281692              9     447847    MCINTOSH      ASHLEY
# 1630732  OH0015085407             18    1712478   HERNANDEZ        JOSE
# 2097775  OH0014663015             18     440280     LUIKART    KATHLEEN
# 1225868  OH0020827481              3    9628603       CLARK       JAMES
# 51941    OH0016490514             21      61352     CATTELL     THERESA
# 1143327  OH0014616624             18     346504    GONZALES        GENE
# ...

# %%
sample2 = sample2.head(500)
sample3 = sample3.head(500)
sample4 = sample4.head(500)

# %%
sample1.to_csv("1_22_sample.csv")
sample2.to_csv("23_44_sample.csv")
sample3.to_csv("45_66_sample.csv")
sample4.to_csv("67_88_sample.csv")
