# %%
import pandas as pd
district1 = pd.read_csv("SWVF_1_22.txt")
district1.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (20,25,26,58,64,74,78,82,87,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     SOS_VOTERID  COUNTY_NUMBER  COUNTY_ID LAST_NAME FIRST_NAME MIDDLE_NAME  \
# 0  OH0011514806             15    9500891   FRANCIS    MICHAEL       JASON
# 1  OH0011577966             10    9500568    LITTLE    WILLIAM           R
# 2  OH0012232589              3    8200338    STOVER   MARGARET           M
# 3  OH0012285520             22      17702     SMITH    MICHELE           R
# 4  OH0014518144             18     139203    NEWTON     PAMELA           A
#
#   SUFFIX DATE_OF_BIRTH REGISTRATION_DATE VOTER_STATUS        ...          \
# 0    NaN    1977-05-17        2012-10-01       ACTIVE        ...
# 1    NaN    1975-04-10        2007-08-10       ACTIVE        ...
# 2    NaN    1954-06-01        1982-09-21       ACTIVE        ...
# 3    NaN    1960-03-03        1991-02-27       ACTIVE        ...
# 4    NaN    1966-01-19        2006-09-26       ACTIVE        ...
#
#   GENERAL-11/03/2015 PRIMARY-03/15/2016 GENERAL-06/07/2016 PRIMARY-09/13/2016  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                  X                  D                NaN                NaN
# 3                  X                  R                NaN                NaN
# 4                  X                  D                NaN                NaN
#
#   GENERAL-11/08/2016  PRIMARY-05/02/2017  PRIMARY-09/12/2017  \
# 0                  X                 NaN                 NaN
# 1                NaN                 NaN                 NaN
# 2                  X                 NaN                 NaN
# 3                  X                 NaN                 NaN
# 4                  X                 NaN                 NaN
#
#    GENERAL-11/07/2017  PRIMARY-05/08/2018 GENERAL-08/07/2018
# 0                 NaN                 NaN                NaN
# 1                 NaN                 NaN                NaN
# 2                   X                   D                NaN
# 3                 NaN                 NaN                NaN
# 4                 NaN                 NaN                NaN
#
# [5 rows x 104 columns]

# %%
district2 = pd.read_csv("SWVF_23_44.txt")
district3 = pd.read_csv("SWVF_45_66.txt")
district4 = pd.read_csv("SWVF_67_88.txt")
district4.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (20,25,26,58,64,73,74,75,78,82,87,93,96,97,100) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (20,25,26,60,73,75,78,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (20,25,26,58,64,74,75,78,82,87,93,97) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     SOS_VOTERID  COUNTY_NUMBER  COUNTY_ID   LAST_NAME FIRST_NAME MIDDLE_NAME  \
# 0  OH0011067584             71    8000564       SMITH    THERESA           K
# 1  OH0011771022             80    9609869  BIRKHEIMER      LINDA           K
# 2  OH0014128431             76     316541      TIPPIE      SCOTT           A
# 3  OH0014215567             76     269261       KUNZE       MARK           P
# 4  OH0014435770             76     126655      DUNNIE   LAWRENCE       JAMES
#
#   SUFFIX DATE_OF_BIRTH REGISTRATION_DATE  VOTER_STATUS        ...          \
# 0    NaN    1947-11-21        1980-09-09        ACTIVE        ...
# 1    NaN    1958-10-31        2000-08-29  CONFIRMATION        ...
# 2    NaN    1970-12-20        2018-05-27        ACTIVE        ...
# 3    NaN    1981-08-13        1999-09-01        ACTIVE        ...
# 4    NaN    1955-10-05        2015-07-07        ACTIVE        ...
#
#   GENERAL-11/03/2015 PRIMARY-03/15/2016 GENERAL-06/07/2016 PRIMARY-09/13/2016  \
# 0                NaN                  R                NaN                NaN
# 1                NaN                  R                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                  D                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#   GENERAL-11/08/2016  PRIMARY-05/02/2017  PRIMARY-09/12/2017  \
# 0                  X                 NaN                 NaN
# 1                  X                 NaN                 NaN
# 2                NaN                 NaN                 NaN
# 3                  X                 NaN                 NaN
# 4                  X                 NaN                 NaN
#
#    GENERAL-11/07/2017  PRIMARY-05/08/2018 GENERAL-08/07/2018
# 0                   X                   R                NaN
# 1                 NaN                 NaN                NaN
# 2                   X                 NaN                NaN
# 3                 NaN                 NaN                NaN
# 4                 NaN                 NaN                NaN
#
# [5 rows x 104 columns]

# %%
voters = pd.concat([district1, district2, district3, district4])
voters.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-7d53a07794bc> in <module>()
# ----> 1 voters = pd.concat([district1, district2, district3, district4])
#       2 voters.head()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     211                        verify_integrity=verify_integrity,
#     212                        copy=copy)
# --> 213     return op.get_result()
#     214
#     215
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     406             new_data = concatenate_block_managers(
#     407                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 408                 copy=self.copy)
#     409             if not self.copy:
#     410                 new_data._consolidate_inplace()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    5201         else:
#    5202             b = make_block(
# -> 5203                 concatenate_join_units(join_units, concat_axis, copy=copy),
#    5204                 placement=placement)
#    5205         blocks.append(b)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in concatenate_join_units(join_units, concat_axis, copy)
#    5326         raise AssertionError("Concatenating join units along axis0")
#    5327
# -> 5328     empty_dtype, upcasted_na = get_empty_dtype_and_na(join_units)
#    5329
#    5330     to_concat = [ju.get_reindexed_values(empty_dtype=empty_dtype,
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in get_empty_dtype_and_na(join_units)
#    5279         # are only null blocks, when same upcasting rules must be applied to
#    5280         # null upcast classes.
# -> 5281         if unit.is_na:
#    5282             null_upcast_classes[upcast_cls].append(dtype)
#    5283         else:
#
# pandas/_libs/properties.pyx in pandas._libs.properties.cache_readonly.__get__()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in is_na(self)
#    5572         chunk_len = max(total_len // 40, 1000)
#    5573         for i in range(0, total_len, chunk_len):
# -> 5574             if not isna(values_flat[i:i + chunk_len]).all():
#    5575                 return False
#    5576
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in isna(obj)
#      43     pandas.isnull: alias of isna
#      44     """
# ---> 45     return _isna(obj)
#      46
#      47
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in _isna_new(obj)
#      56         raise NotImplementedError("isna is not defined for MultiIndex")
#      57     elif isinstance(obj, (ABCSeries, np.ndarray, ABCIndexClass)):
# ---> 58         return _isna_ndarraylike(obj)
#      59     elif isinstance(obj, ABCGeneric):
#      60         return obj._constructor(obj._data.isna(func=isna))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/dtypes/missing.py in _isna_ndarraylike(obj)
#     144             else:
#     145                 result = np.empty(shape, dtype=bool)
# --> 146                 vec = lib.isnaobj(values.ravel())
#     147                 result[...] = vec.reshape(shape)
#     148
#
# KeyboardInterrupt:

# %%
print(district1.shape)
print(district2.shape)
print(district3.shape)
print(district4.shape)
print(voters.shape)

# %%
voters = voters.sample(frac=1)
cutoff = round(voters.shape[0] * 0.8)
cutoff

# %%
train = voters[:cutoff]
test = voters[cutoff:]
train.head()

# %%
sample_train = train[:1000]
sample_test = test[:1000]

# %%
import numpy as np
train_2016_general = sample_train[train.columns[np.arange(0, 99)]]
test_2016_general = sample_test[test.columns[np.arange(0, 99)]]
train_2016_general.head()

# %%
train_2016_general["GENERAL-11/08/2016"].count()

# %%
len(train_2016_general["GENERAL-11/08/2016"])

# %%
list(train_2016_general)

# %%
train_recent_2016 = train_2016_general[voters.columns[np.arange(84, 99)]]
test_recent_2016 = test_2016_general[voters.columns[np.arange(84, 99)]]
train_recent_2016.head()

# %%
from sklearn.model_selection import train_test_split

columns = voters.columns[np.arange(84, 98)]
sample = voters[:2000]
all_X = sample[columns].fillna(0).astype("bool")
all_y = sample['GENERAL-11/08/2016'].fillna(0).astype("bool")

train_X, test_X, train_y, test_y = train_test_split(all_X, all_y, test_size=0.20)
train_X.head()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
lr = LogisticRegression()
lr.fit(train_X, train_y)
predictions = lr.predict(test_X)
accuracy = accuracy_score(test_y, predictions)
accuracy

# %%
train_X.fillna(0).astype("bool")

# %%
train_recent_2014 = train_2016_general[voters.columns[np.arange(84, 92)]]
test_recent_2014 = test_2016_general[voters.columns[np.arange(84, 92)]]
train_recent_2014.head()

# %%
columns_2014 = voters.columns[np.arange(84, 91)]
sample = voters[:2000]
all_X = sample[columns_2014].fillna(0).astype("bool")
all_y = sample['GENERAL-11/04/2014'].fillna(0).astype("bool")

train_X, test_X, train_y, test_y = train_test_split(all_X, all_y, test_size=0.20)
train_X.head()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
lr = LogisticRegression()
lr.fit(train_X, train_y)
predictions = lr.predict(test_X)
accuracy = accuracy_score(test_y, predictions)
accuracy

# %%
location_features = [
 'CONGRESSIONAL_DISTRICT',
 'COURT_OF_APPEALS',
 'LIBRARY',
 'STATE_BOARD_OF_EDUCATION',
 'STATE_REPRESENTATIVE_DISTRICT',
 'STATE_SENATE_DISTRICT'
]

all_X = sample[location_features].fillna(0)
all_y = sample['GENERAL-11/08/2016'].fillna(0).astype("bool")

train_X, test_X, train_y, test_y = train_test_split(all_X, all_y, test_size=0.20)
train_X.head()

# %%
lr = LogisticRegression()
lr.fit(train_X, train_y)
predictions = lr.predict(test_X)
accuracy = accuracy_score(test_y, predictions)
accuracy

# %%
from datetime import datetime, timedelta

def date_to_days(date):
    start = datetime(year=2000, month=1, day=1)
    date = datetime.strptime(date, "%Y-%m-%d")
    diff = start - date
    return diff.days   

date_features = [
 'DATE_OF_BIRTH',
 'REGISTRATION_DATE'
]
float_cols = ["float_dob", "float_reg"]

sample = voters[:2000]
dates = sample[date_features]
dates["float_dob"] = dates['DATE_OF_BIRTH'].apply(date_to_days)
dates["float_reg"] = dates['REGISTRATION_DATE'].apply(date_to_days)
dates.head()

all_X = dates[float_cols]
all_y = sample['GENERAL-11/08/2016'].fillna(0).astype("bool")

train_X, test_X, train_y, test_y = train_test_split(all_X, all_y, test_size=0.20)
train_X.head()

# %%
lr = LogisticRegression()
lr.fit(train_X, train_y)
predictions = lr.predict(test_X)
accuracy = accuracy_score(test_y, predictions)
accuracy

# %%
date_vote_features = [
 'DATE_OF_BIRTH',
 'REGISTRATION_DATE',
 'PRIMARY-03/04/2008',
 'PRIMARY-10/14/2008',
 'GENERAL-11/04/2008',
 'GENERAL-11/18/2008',
 'PRIMARY-05/05/2009',
 'PRIMARY-09/08/2009',
 'PRIMARY-09/15/2009',
 'PRIMARY-09/29/2009',
 'GENERAL-11/03/2009',
 'PRIMARY-05/04/2010',
 'PRIMARY-07/13/2010',
 'PRIMARY-09/07/2010',
 'GENERAL-11/02/2010',
 'PRIMARY-05/03/2011',
 'PRIMARY-09/13/2011',
 'GENERAL-11/08/2011',
 'PRIMARY-03/06/2012',
 'GENERAL-11/06/2012',
 'PRIMARY-05/07/2013',
 'PRIMARY-09/10/2013',
 'PRIMARY-10/01/2013',
 'GENERAL-11/05/2013',
 'PRIMARY-05/06/2014',
 'GENERAL-11/04/2014',
 'PRIMARY-05/05/2015',
 'PRIMARY-09/15/2015',
 'GENERAL-11/03/2015',
 'PRIMARY-03/15/2016',
 'GENERAL-06/07/2016',
 'PRIMARY-09/13/2016'
]

all_X = sample[date_vote_features]
all_X["float_dob"] = all_X['DATE_OF_BIRTH'].apply(date_to_days)
all_X["float_reg"] = all_X['REGISTRATION_DATE'].apply(date_to_days)
all_X.head()

# %%
vote_features = [
 'PRIMARY-03/04/2008',
 'PRIMARY-10/14/2008',
 'GENERAL-11/04/2008',
 'GENERAL-11/18/2008',
 'PRIMARY-05/05/2009',
 'PRIMARY-09/08/2009',
 'PRIMARY-09/15/2009',
 'PRIMARY-09/29/2009',
 'GENERAL-11/03/2009',
 'PRIMARY-05/04/2010',
 'PRIMARY-07/13/2010',
 'PRIMARY-09/07/2010',
 'GENERAL-11/02/2010',
 'PRIMARY-05/03/2011',
 'PRIMARY-09/13/2011',
 'GENERAL-11/08/2011',
 'PRIMARY-03/06/2012',
 'GENERAL-11/06/2012',
 'PRIMARY-05/07/2013',
 'PRIMARY-09/10/2013',
 'PRIMARY-10/01/2013',
 'GENERAL-11/05/2013',
 'PRIMARY-05/06/2014',
 'GENERAL-11/04/2014',
 'PRIMARY-05/05/2015',
 'PRIMARY-09/15/2015',
 'GENERAL-11/03/2015',
 'PRIMARY-03/15/2016',
 'GENERAL-06/07/2016',
 'PRIMARY-09/13/2016'
]

for col in vote_features:
    all_X[col] = all_X[col].fillna(0).astype("bool")
    
all_X.head()

# %%
cleaned_features = [
 "float_dob",
 "float_reg",
 'PRIMARY-03/04/2008',
 'PRIMARY-10/14/2008',
 'GENERAL-11/04/2008',
 'GENERAL-11/18/2008',
 'PRIMARY-05/05/2009',
 'PRIMARY-09/08/2009',
 'PRIMARY-09/15/2009',
 'PRIMARY-09/29/2009',
 'GENERAL-11/03/2009',
 'PRIMARY-05/04/2010',
 'PRIMARY-07/13/2010',
 'PRIMARY-09/07/2010',
 'GENERAL-11/02/2010',
 'PRIMARY-05/03/2011',
 'PRIMARY-09/13/2011',
 'GENERAL-11/08/2011',
 'PRIMARY-03/06/2012',
 'GENERAL-11/06/2012',
 'PRIMARY-05/07/2013',
 'PRIMARY-09/10/2013',
 'PRIMARY-10/01/2013',
 'GENERAL-11/05/2013',
 'PRIMARY-05/06/2014',
 'GENERAL-11/04/2014',
 'PRIMARY-05/05/2015',
 'PRIMARY-09/15/2015',
 'GENERAL-11/03/2015',
 'PRIMARY-03/15/2016',
 'GENERAL-06/07/2016',
 'PRIMARY-09/13/2016'
]

all_X = all_X[cleaned_features]
all_X.head()

# %%
all_y = sample['GENERAL-11/08/2016'].fillna(0).astype("bool")

train_X, test_X, train_y, test_y = train_test_split(all_X, all_y, test_size=0.20)

lr = LogisticRegression()
lr.fit(train_X, train_y)
predictions = lr.predict(test_X)
accuracy = accuracy_score(test_y, predictions)
accuracy

# %%
date_vote_features = [
 'DATE_OF_BIRTH',
 'REGISTRATION_DATE',
 'PRIMARY-03/06/2012',
 'GENERAL-11/06/2012',
 'PRIMARY-05/07/2013',
 'PRIMARY-09/10/2013',
 'PRIMARY-10/01/2013',
 'GENERAL-11/05/2013',
 'PRIMARY-05/06/2014',
 'GENERAL-11/04/2014',
 'PRIMARY-05/05/2015',
 'PRIMARY-09/15/2015',
 'GENERAL-11/03/2015',
 'PRIMARY-03/15/2016',
 'GENERAL-06/07/2016',
 'PRIMARY-09/13/2016'
]

dates_and_votes = sample[date_vote_features]
dates_and_votes["float_dob"] = dates_and_votes['DATE_OF_BIRTH'].apply(date_to_days)
dates_and_votes["float_reg"] = dates_and_votes['REGISTRATION_DATE'].apply(date_to_days)

vote_features = [
 'PRIMARY-03/06/2012',
 'GENERAL-11/06/2012',
 'PRIMARY-05/07/2013',
 'PRIMARY-09/10/2013',
 'PRIMARY-10/01/2013',
 'GENERAL-11/05/2013',
 'PRIMARY-05/06/2014',
 'GENERAL-11/04/2014',
 'PRIMARY-05/05/2015',
 'PRIMARY-09/15/2015',
 'GENERAL-11/03/2015',
 'PRIMARY-03/15/2016',
 'GENERAL-06/07/2016',
 'PRIMARY-09/13/2016'
]

for col in vote_features:
    dates_and_votes[col] = dates_and_votes[col].fillna(0).astype("bool")
    
cleaned_features = [
 "float_dob",
 "float_reg",
 'PRIMARY-03/06/2012',
 'GENERAL-11/06/2012',
 'PRIMARY-05/07/2013',
 'PRIMARY-09/10/2013',
 'PRIMARY-10/01/2013',
 'GENERAL-11/05/2013',
 'PRIMARY-05/06/2014',
 'GENERAL-11/04/2014',
 'PRIMARY-05/05/2015',
 'PRIMARY-09/15/2015',
 'GENERAL-11/03/2015',
 'PRIMARY-03/15/2016',
 'GENERAL-06/07/2016',
 'PRIMARY-09/13/2016'
]

dates_and_votes = dates_and_votes[cleaned_features]

all_X = dates_and_votes
all_y = sample['GENERAL-11/08/2016'].fillna(0).astype("bool")

train_X, test_X, train_y, test_y = train_test_split(all_X, all_y, test_size=0.20)
train_X.head()

# %%
lr = LogisticRegression()
lr.fit(train_X, train_y)
predictions = lr.predict(test_X)
accuracy = accuracy_score(test_y, predictions)
accuracy

# %%
location_features = [
 'CONGRESSIONAL_DISTRICT',
 'COURT_OF_APPEALS',
 'LIBRARY',
 'STATE_BOARD_OF_EDUCATION',
 'STATE_REPRESENTATIVE_DISTRICT',
 'STATE_SENATE_DISTRICT'
]

locations = sample[location_features]
location_dummies = pd.get_dummies(locations, dummy_na = True)
location_dummies.head()

# %%
congressional_dummies = pd.get_dummies(locations["CONGRESSIONAL_DISTRICT"], prefix = "district")
congressional_dummies.head()

# %%
court_dummies = pd.get_dummies(locations["COURT_OF_APPEALS"], prefix = "court")
court_dummies.head()

# %%
sum(pd.notnull(locations["LIBRARY"]))

# %%
board_dummies = pd.get_dummies(locations["STATE_BOARD_OF_EDUCATION"], prefix = "board")
board_dummies.head()

# %%
representative_dummies = pd.get_dummies(locations["STATE_REPRESENTATIVE_DISTRICT"], prefix = "representative")
representative_dummies.head()

# %%
senate_dummies = pd.get_dummies(locations["STATE_SENATE_DISTRICT"], prefix = "senate")
senate_dummies.head()

# %%
all_dummies = pd.concat(
    [congressional_dummies, court_dummies, representative_dummies, representative_dummies, senate_dummies], axis=1
)
all_dummies.head()

# %%
all_X = all_dummies
all_y = sample['GENERAL-11/08/2016'].fillna(0).astype("bool")

train_X, test_X, train_y, test_y = train_test_split(all_X, all_y, test_size=0.20)

lr = LogisticRegression()
lr.fit(train_X, train_y)
predictions = lr.predict(test_X)
accuracy = accuracy_score(test_y, predictions)
accuracy

# %%
dummies_and_history = pd.concat([all_dummies, dates_and_votes], axis=1)
dummies_and_history.head()

# %%
all_X = dummies_and_history
all_y = sample['GENERAL-11/08/2016'].fillna(0).astype("bool")

train_X, test_X, train_y, test_y = train_test_split(all_X, all_y, test_size=0.20)

lr = LogisticRegression()
lr.fit(train_X, train_y)
predictions = lr.predict(test_X)
accuracy = accuracy_score(test_y, predictions)
accuracy

# %%
sample
